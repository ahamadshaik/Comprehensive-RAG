# %% [markdown]
# # Evaluation demo
#
# Runs the retrieval metric script (no LLM generation required).

# %%
import subprocess, sys
from pathlib import Path

root = Path.cwd()
if not (root / "eval").is_dir():
    root = root.parent
subprocess.check_call([sys.executable, str(root / "eval" / "evaluate.py")], cwd=root)
