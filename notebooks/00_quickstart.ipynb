# %% [markdown]
# # Comprehensive-RAG quickstart
#
# Run ingestion then query from the project root with `.env` configured.

# %%
from app.ingest import build_index
from app.rag import answer

build_index()
resp = answer("What modules are described in the architecture doc?")
resp
